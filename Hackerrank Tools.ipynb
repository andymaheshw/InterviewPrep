# %%
import sys 

dt_len = sys.stdin.readline()
arr1 = [int(dp) for dp in sys.stdin.readline()]

# %%
import sys

for line in sys.stdin:
    print line

# %%
s = "hello"

# %%
set("abc") - set("cde")
# Out:
# {'a', 'b'}

# %%
set("cde")
# Out:
# {'c', 'd', 'e'}
